# %% [markdown]
# ## Input and Output

# %%
import pandas as pd

url = "https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv"

baby_names = pd.read_csv(url)
baby_names
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 77282           2012    MALE      BLACK NON HISP             CAYDEN     19
# 77283           2013  FEMALE  WHITE NON HISPANIC           Margaret     25
# 77284           2013  FEMALE  WHITE NON HISPANIC              Tamar     10
# 77285           2013  FEMALE  WHITE NON HISPANIC             Amanda     13
# 77286           2012  FEMALE            HISPANIC               ANNA     10
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 77282    52
# 77283    67
# 77284    82
# 77285    79
# 77286    79
#
# [77287 rows x 6 columns]

# %% [markdown]
# ### Export DataFrame to CSV File
#     * the to_csv method exports a DataFrame to a CSV file.
#     * its first argument is the filename.
#     * by default, pandas will include the index. Set the index parameter to False to exclude the index.
#     * the columns parameter limits the exported columns.

# %%
baby_names.to_csv("data/baby_names.csv", index=False, columns=["Year of Birth", "Child's First Name","Count"])

# %% [markdown]
# ### Import Excel File into Pandas
#     * the read_excel function reads an Excel file/workbook into a DataFrame.
#     * use the sheet_name parameter if the workbook contains multiple worksheets. Pass a single worksheet name or a list of worksheet names/index positions.
#     * pass the sheet_name parameter an argument of None to include all worksheets.
#     * pandas will store multiple worksheets in a Python dictionary. The keys will be the worksheet names, and the values will be the DataFrames.

# %%
pd.read_excel("data/Data - Single Worksheet.xlsx")
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
dic = pd.read_excel("data/Data - Multiple Worksheets.xlsx", sheet_name=["Data 1","Data 2"])

# %%
df1 = dic["Data 1"]
df2 = dic["Data 2"]

# %%
df2
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
df1
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
dic = pd.read_excel("data/Data - Multiple Worksheets.xlsx", sheet_name=[0, 1]) # same as the above 
df1 = dic[0]
df2 = dic[1]

# %%
df1
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
df2
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
dic = pd.read_excel("data/Data - Multiple Worksheets.xlsx", sheet_name=None) # brings in all the worksheets
dic
# Out:
# {'Data 1':   First Name Last Name           City Gender
#  0    Brandon     James          Miami      M
#  1       Sean   Hawkins         Denver      M
#  2       Judy       Day    Los Angeles      F
#  3     Ashley      Ruiz  San Francisco      F
#  4  Stephanie     Gomez       Portland      F,
#  'Data 2':   First Name Last Name           City Gender
#  0     Parker     Power        Raleigh      F
#  1    Preston  Prescott   Philadelphia      F
#  2    Ronaldo   Donaldo         Bangor      M
#  3      Megan   Stiller  San Francisco      M
#  4     Bustin    Jieber         Austin      F}

# %% [markdown]
# ### Export Excel File from Pandas
#     * the ExcelWriter class writes one or more DataFrames to an Excel file.
#     * use a context manager (the with keyword) in combination with the ExcelWriter object and an assigned variable.
#     * invoke the to_excel method on every DataFrame to include in the Excel workbook and pass in the ExcelWriter object as the first argument.
#     * the to_excel method supports sheet_name, index, and columns parameters.

# %%
baby_names
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 77282           2012    MALE      BLACK NON HISP             CAYDEN     19
# 77283           2013  FEMALE  WHITE NON HISPANIC           Margaret     25
# 77284           2013  FEMALE  WHITE NON HISPANIC              Tamar     10
# 77285           2013  FEMALE  WHITE NON HISPANIC             Amanda     13
# 77286           2012  FEMALE            HISPANIC               ANNA     10
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 77282    52
# 77283    67
# 77284    82
# 77285    79
# 77286    79
#
# [77287 rows x 6 columns]

# %%
females = baby_names[baby_names["Gender"] == "FEMALE"]
females
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 77280           2013  FEMALE            HISPANIC              Julia     23
# 77283           2013  FEMALE  WHITE NON HISPANIC           Margaret     25
# 77284           2013  FEMALE  WHITE NON HISPANIC              Tamar     10
# 77285           2013  FEMALE  WHITE NON HISPANIC             Amanda     13
# 77286           2012  FEMALE            HISPANIC               ANNA     10
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# 4        53
# ...     ...
# 77280    65
# 77283    67
# 77284    82
# 77285    79
# 77286    79
#
# [39426 rows x 6 columns]

# %%
males = baby_names[baby_names["Gender"] == "MALE"]
males
# Out:
#        Year of Birth Gender                   Ethnicity Child's First Name  \
# 363             2013   MALE                    HISPANIC              Jared
# 416             2013   MALE                    HISPANIC             Jariel
# 547             2011   MALE  ASIAN AND PACIFIC ISLANDER              AARAV
# 548             2011   MALE  ASIAN AND PACIFIC ISLANDER              AARON
# 549             2011   MALE  ASIAN AND PACIFIC ISLANDER              ABDUL
# ...              ...    ...                         ...                ...
# 77273           2011   MALE                    HISPANIC           ANDERSON
# 77277           2011   MALE                    HISPANIC            GERARDO
# 77279           2013   MALE          BLACK NON HISPANIC            Derrick
# 77281           2011   MALE  ASIAN AND PACIFIC ISLANDER            IBRAHIM
# 77282           2012   MALE              BLACK NON HISP             CAYDEN
#
#        Count  Rank
# 363       25    80
# 416       25    80
# 547       15    51
# 548       51    19
# 549       20    46
# ...      ...   ...
# 77273     33    71
# 77277     12    92
# 77279     10    62
# 77281     17    49
# 77282     19    52
#
# [37861 rows x 6 columns]

# %%
with pd.ExcelWriter("data/NYC Baby Data.xlsx") as xl_file:
    females.to_excel(xl_file, sheet_name="Females", index=False)
    males.to_excel(xl_file, sheet_name="Males", index=False, columns=["Year of Birth", "Child's First Name", "Rank"])
