# %%
import pandas as pd

# Series
# A Series is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.). 
# The axis labels are collectively referred to as the index. A Series is like a fixed-size dictionary in that you can get and set values by index label.

pd.Series(data=["Chocolate", "Vanilla", "Strawberry","Rum Raisin"])
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: str

# %%
pd.Series(data=[1, 2, 3, 4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
registration = [True, False, True, False]
pd.Series(data=registration)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
# Create a Series from a Dictionary
# Keys are used as index labels and values are used as the data for the Series. The values in the Series will be in the same order as the keys in the dictionary.
sushi = {
    "Salmon": "Orange",
    "Tuna": "Red",
    "Eel" : "Brown"
}
pd.Series(data=sushi)
# Out:
# Salmon    Orange
# Tuna         Red
# Eel        Brown
# dtype: str

# %%
prices = pd.Series([2.99,4.45,3.46])
prices
# Out:
# 0    2.99
# 1    4.45
# 2    3.46
# dtype: float64

# %%
# Series methods
prices.sum()
# Out:
# np.float64(10.9)

# %%
prices.product()
# Out:
# np.float64(46.03703000000001)

# %%
prices.mean()
# Out:
# np.float64(3.6333333333333333)

# %%
prices.std()
# Out:
# np.float64(0.7452739988308551)

# %%
# Series Attributes
adjectives = pd.Series(["Smart","Handsome","Charming","Brilliant","Humble","Smart"])

# %%
adjectives.size
# Out:
# 6

# %%
adjectives.is_unique
# Out:
# False

# %%
# composition is made up of values and index
adjectives.values
# Out:
# <StringArray>
# ['Smart', 'Handsome', 'Charming', 'Brilliant', 'Humble', 'Smart']
# Length: 6, dtype: str

# %%
adjectives.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
type(adjectives.values)
# Out:
# pandas.arrays.StringArray

# %%
type(adjectives.index)
# Out:
# pandas.RangeIndex

# %%
# a parameters is the name of the input, an argument is the actual value passed to the function.

fruits = ["Apple", "Banana", "Cherry","Orange","Plum","Durian"]
weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday","Monday"]
pd.Series(fruits, weekdays)
# Out:
# Monday        Apple
# Tuesday      Banana
# Wednesday    Cherry
# Thursday     Orange
# Friday         Plum
# Monday       Durian
# dtype: str

# %%
pd.Series(weekdays, fruits)
# Out:
# Apple        Monday
# Banana      Tuesday
# Cherry    Wednesday
# Orange     Thursday
# Plum         Friday
# Durian       Monday
# dtype: str

# %%
pd.Series(data=fruits, index=weekdays)
# Out:
# Monday        Apple
# Tuesday      Banana
# Wednesday    Cherry
# Thursday     Orange
# Friday         Plum
# Monday       Durian
# dtype: str

# %%
pd.Series(index=weekdays, data=fruits)
# Out:
# Monday        Apple
# Tuesday      Banana
# Wednesday    Cherry
# Thursday     Orange
# Friday         Plum
# Monday       Durian
# dtype: str

# %%
pd.Series(fruits, index=weekdays)
# Out:
# Monday        Apple
# Tuesday      Banana
# Wednesday    Cherry
# Thursday     Orange
# Friday         Plum
# Monday       Durian
# dtype: str

# %%
fruits_series = pd.Series(fruits, index=weekdays)
fruits_series.ndim
# Out:
# 1

# %%
fruits_df = pd.DataFrame(fruits_series)
fruits_df.ndim
# Out:
# 2

# %%
fruits_df.index
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Monday'], dtype='str')

# %%
fruits_df.loc['Monday']
# Out:
#              0
# Monday   Apple
# Monday  Durian

# %%
fruits_df.iloc[0]
# Out:
# 0    Apple
# Name: Monday, dtype: str

# %%
fruits_df.index
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Monday'], dtype='str')

# %%
fruits_series.index
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Monday'], dtype='str')

# %%
fruits_df.loc['Monday']
# Out:
#              0
# Monday   Apple
# Monday  Durian

# %%
pokemon = pd.read_csv("data/pokemon.csv", usecols=["Name"]).squeeze("columns")
google  = pd.read_csv("data/google_stock_price.csv", usecols=["Price"]).squeeze("columns")

# %%
type(google)
# Out:
# pandas.Series

# %%
len(google)
# Out:
# 4793

# %%
list(pokemon)
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran♀',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alcremie',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Annihilape',
#  'Anorith',
#  'Appletun',
#  'Applin',
#  'Araquanid',
#  'Arbok',
#  'Arboliva',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Arctibax',
#  'Arctovish',
#  'Arctozolt',
#  'Ariados',
#  'Armaldo',
#  'Armarouge',
#  'Aromatisse',
#  'Aron',
#  'Arrokuda',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Barraskewda',
#  'Basculegion',
#  'Basculin',
#  'Bastiodon',
#  'Baxcalibur',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellibolt',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bewear',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
# ...

# %%
dict(pokemon)
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'Charmander',
#  4: 'Charmeleon',
#  5: 'Charizard',
#  6: 'Squirtle',
#  7: 'Wartortle',
#  8: 'Blastoise',
#  9: 'Caterpie',
#  10: 'Metapod',
#  11: 'Butterfree',
#  12: 'Weedle',
#  13: 'Kakuna',
#  14: 'Beedrill',
#  15: 'Pidgey',
#  16: 'Pidgeotto',
#  17: 'Pidgeot',
#  18: 'Rattata',
#  19: 'Raticate',
#  20: 'Spearow',
#  21: 'Fearow',
#  22: 'Ekans',
#  23: 'Arbok',
#  24: 'Pikachu',
#  25: 'Raichu',
#  26: 'Sandshrew',
#  27: 'Sandslash',
#  28: 'Nidoran♀',
#  29: 'Nidorina',
#  30: 'Nidoqueen',
#  31: 'Nidoran♂',
#  32: 'Nidorino',
#  33: 'Nidoking',
#  34: 'Clefairy',
#  35: 'Clefable',
#  36: 'Vulpix',
#  37: 'Ninetales',
#  38: 'Jigglypuff',
#  39: 'Wigglytuff',
#  40: 'Zubat',
#  41: 'Golbat',
#  42: 'Oddish',
#  43: 'Gloom',
#  44: 'Vileplume',
#  45: 'Paras',
#  46: 'Parasect',
#  47: 'Venonat',
#  48: 'Venomoth',
#  49: 'Diglett',
#  50: 'Dugtrio',
#  51: 'Meowth',
#  52: 'Persian',
#  53: 'Psyduck',
# ...

# %%
max(google)
# Out:
# 151.863495

# %%
"Kakuna" in pokemon.values  # defaults to searching the index, so we need to specify that we want to search the values
# Out:
# True

# %%
google.sort_values()
# Out:
# 10        2.470490
# 0         2.490664
# 13        2.509095
# 11        2.514326
# 1         2.515820
#            ...
# 4336    150.000000
# 4341    150.000000
# 4346    150.141754
# 4345    151.000000
# 4395    151.863495
# Name: Price, Length: 4793, dtype: float64

# %%
google.sort_index()
# Out:
# 0         2.490664
# 1         2.515820
# 2         2.758411
# 3         2.770615
# 4         2.614201
#            ...
# 4788    132.080002
# 4789    132.998001
# 4790    135.570007
# 4791    137.050003
# 4792    138.429993
# Name: Price, Length: 4793, dtype: float64

# %%
google.sort_values(ascending=False)
# Out:
# 4395    151.863495
# 4345    151.000000
# 4346    150.141754
# 4341    150.000000
# 4336    150.000000
#            ...
# 1         2.515820
# 11        2.514326
# 13        2.509095
# 0         2.490664
# 10        2.470490
# Name: Price, Length: 4793, dtype: float64

# %%
pokemon = pd.read_csv("data/pokemon.csv", index_col='Name', usecols=['Name','Type']).squeeze("columns")

# %%
pokemon.sort_values()
# Out:
# Name
# Wurmple                Bug
# Accelgor               Bug
# Shelmet                Bug
# Illumise               Bug
# Cascoon                Bug
#                   ...
# Drednaw        Water, Rock
# Tirtouga       Water, Rock
# Relicanth      Water, Rock
# Carracosta     Water, Rock
# Empoleon      Water, Steel
# Name: Type, Length: 1010, dtype: str

# %%
pokemon.sort_index()
# Out:
# Name
# Abomasnow        Grass, Ice
# Abra                Psychic
# Absol                  Dark
# Accelgor                Bug
# Aegislash      Steel, Ghost
#                   ...
# Zoroark                Dark
# Zorua                  Dark
# Zubat        Poison, Flying
# Zweilous       Dark, Dragon
# Zygarde      Dragon, Ground
# Name: Type, Length: 1010, dtype: str

# %%
pokemon
# Out:
# Name
# Bulbasaur          Grass, Poison
# Ivysaur            Grass, Poison
# Venusaur           Grass, Poison
# Charmander                  Fire
# Charmeleon                  Fire
#                       ...
# Iron Valiant     Fairy, Fighting
# Koraidon        Fighting, Dragon
# Miraidon        Electric, Dragon
# Walking Wake       Water, Dragon
# Iron Leaves       Grass, Psychic
# Name: Type, Length: 1010, dtype: str

# %%
# Extract Series Values by Index Position
pokemon.iloc[3] # returns the value at row 4
pokemon.iloc[0:3] # returns the values at rows 1-4 (the stop index is exclusive)
pokemon.iloc[-1] # returns the value at the last row
pokemon.iloc[-3] # returns the values at the last 3rd rows
pokemon.iloc[-3:] # returns the values at the last 3 rows   
pokemon.iloc[:-3] # returns the values at all rows except the last 3
pokemon.iloc[:4] # returns the values of first 4 rows
pokemon.iloc[[2,4,6]] # returns the values at rows 3,5,7
# Out:
# Name
# Venusaur      Grass, Poison
# Charmeleon             Fire
# Squirtle              Water
# Name: Type, dtype: str

# %%
# Extract Series Values by Index Label
pokemon.loc["Bulbasaur"] # returns the value at index label "Bulbasaur"
pokemon["Bulbasaur"] # returns the value at index label "Bulbasaur"
pokemon.loc[["Bulbasaur","Charmander","Squirtle"]] # returns the values at index labels "Bulbasaur", "Charmander", and "Squirtle"
pokemon[["Bulbasaur","Charmander","Squirtle"]] # returns the values at index labels "Bulbasaur", "Charmander", and "Squirtle"

pokemon.get("Bulbasaur") # returns the value at index label "Bulbasaur"
pokemon.get(["Bulbasaur","Charmander","Squirtle"]) # returns the values at index labels "Bulbasaur", "Charmander", and "Squirtle"
pokemon.get("Pika", "Not Found") # returns "Not Found" since "Pika" is not an index label in the Series
pokemon.get("Pika") # returns NaN since "Pika" is not an index label in the Series
pokemon.get(["Bulbasaur","Charmander","Squirtle","Pika"], "Not Found") # returns the values at index labels "Bulbasaur", "Charmander", and "Squirtle", and "Not Found" for "Pika" since it is not an index label in the Series
# Out:
# 'Not Found'

# %%
# Overwrite a Series Value
pokemon.loc["Bulbasaur"] = "Grass/Poison"
pokemon.loc["Bulbasaur"]
# Out:
# 'Grass/Poison'

# %%
pokemon.iloc[0] = "Grass, Poison"
pokemon.iloc[0]
# Out:
# 'Grass, Poison'

# %%
pokemon.iloc[[1,2,4]] = ["Fire", "Water", "Bug"]
pokemon.iloc[[1,2,4]]
# Out:
# Name
# Ivysaur        Fire
# Venusaur      Water
# Charmeleon      Bug
# Name: Type, dtype: str

# %%
# Math Methods on Series Objects
google
# Out:
# 0         2.490664
# 1         2.515820
# 2         2.758411
# 3         2.770615
# 4         2.614201
#            ...
# 4788    132.080002
# 4789    132.998001
# 4790    135.570007
# 4791    137.050003
# 4792    138.429993
# Name: Price, Length: 4793, dtype: float64

# %%
google.count() # returns the number of non-missing values in the Series
google.size # returns the total number of values in the Series, including missing values
# Out:
# 4793

# %%
google.sum() # returns the sum of the values in the Series, excluding missing values
# Out:
# np.float64(192733.129338)

# %%
google.product() # returns the product of the values in the Series, excluding missing values
# Out:
# /home/samlau/Python/ML-Projects-and-tutorials/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# np.float64(inf)

# %%
google.mean() # returns the mean of the values in the Series, excluding missing values
# Out:
# np.float64(40.211376870018775)

# %%
google.std() # returns the standard deviation of the values in the Series, excluding missing values
# Out:
# np.float64(37.274752943868094)

# %%
google.max() # returns the maximum value in the Series, excluding missing values
# Out:
# np.float64(151.863495)

# %%
google.median() # returns the median of the values in the Series, excluding missing values
# Out:
# np.float64(26.327717)

# %%
google.mode() # returns the mode of the values in the Series, excluding missing values
# Out:
# 0    14.719826
# 1    49.000000
# Name: Price, dtype: float64

# %%
google.describe() # returns a summary of statistics for the values in the Series, excluding missing values
# Out:
# count    4793.000000
# mean       40.211377
# std        37.274753
# min         2.470490
# 25%        12.767395
# 50%        26.327717
# 75%        56.311001
# max       151.863495
# Name: Price, dtype: float64

# %%
google
# Out:
# 0         2.490664
# 1         2.515820
# 2         2.758411
# 3         2.770615
# 4         2.614201
#            ...
# 4788    132.080002
# 4789    132.998001
# 4790    135.570007
# 4791    137.050003
# 4792    138.429993
# Name: Price, Length: 4793, dtype: float64

# %%
# Broadcasting - the ability of pandas to perform operations on Series and DataFrame objects that have different shapes and sizes. 
# When performing an operation between two Series or DataFrame objects, pandas will automatically align the data based on the index labels 
# and perform the operation element-wise. If one of the Series or DataFrame objects has a smaller shape than the other, pandas will "broadcast" 
# the smaller object across the larger object to perform the operation. 
# This allows for efficient and flexible data manipulation without having to manually reshape or align the data.

google + 10 # adds 10 to each value in the Series, broadcasting the scalar value across the Series
# Out:
# 0        12.490664
# 1        12.515820
# 2        12.758411
# 3        12.770615
# 4        12.614201
#            ...
# 4788    142.080002
# 4789    142.998001
# 4790    145.570007
# 4791    147.050003
# 4792    148.429993
# Name: Price, Length: 4793, dtype: float64

# %%
google - 10 # subtracts 10 from each value in the Series, broadcasting the scalar value across the Series
# Out:
# 0        -7.509336
# 1        -7.484180
# 2        -7.241589
# 3        -7.229385
# 4        -7.385799
#            ...
# 4788    122.080002
# 4789    122.998001
# 4790    125.570007
# 4791    127.050003
# 4792    128.429993
# Name: Price, Length: 4793, dtype: float64

# %%
google * 2 # multiplies each value in the Series by 2, broadcasting the scalar value across the Series
# Out:
# 0         4.981328
# 1         5.031640
# 2         5.516822
# 3         5.541230
# 4         5.228402
#            ...
# 4788    264.160004
# 4789    265.996002
# 4790    271.140014
# 4791    274.100006
# 4792    276.859986
# Name: Price, Length: 4793, dtype: float64

# %%
google / 2 # divides each value in the Series by 2, broadcasting the scalar value across the Series
# Out:
# 0        1.245332
# 1        1.257910
# 2        1.379206
# 3        1.385307
# 4        1.307100
#           ...
# 4788    66.040001
# 4789    66.499000
# 4790    67.785004
# 4791    68.525002
# 4792    69.214996
# Name: Price, Length: 4793, dtype: float64

# %%
# Values Count - the number of occurrences of each unique value in the Series. This can be useful for understanding the distribution 
# of values in the Series and identifying any patterns or trends in the data. The value_counts() method returns a Series containing 
# counts of unique values in the original Series, sorted in descending order by default.

pokemon.value_counts()
# Out:
# Type
# Water               75
# Normal              74
# Grass               46
# Psychic             39
# Fire                36
#                     ..
# Rock, Electric       1
# Dark, Ground         1
# Dragon, Dark         1
# Fairy, Fighting      1
# Fighting, Dragon     1
# Name: count, Length: 200, dtype: int64

# %%
pokemon.value_counts(normalize=True) # returns the relative frequencies of each unique value in the Series, normalized to sum to 1
# Out:
# Type
# Water               0.074257
# Normal              0.073267
# Grass               0.045545
# Psychic             0.038614
# Fire                0.035644
#                       ...
# Rock, Electric      0.000990
# Dark, Ground        0.000990
# Dragon, Dark        0.000990
# Fairy, Fighting     0.000990
# Fighting, Dragon    0.000990
# Name: proportion, Length: 200, dtype: float64

# %%
# The apply() method allows you to apply a function to each element in the Series. This can be useful for performing custom 
# transformations or calculations on the data.

pokemon
# Out:
# Name
# Bulbasaur          Grass, Poison
# Ivysaur                     Fire
# Venusaur                   Water
# Charmander                  Fire
# Charmeleon                   Bug
#                       ...
# Iron Valiant     Fairy, Fighting
# Koraidon        Fighting, Dragon
# Miraidon        Electric, Dragon
# Walking Wake       Water, Dragon
# Iron Leaves       Grass, Psychic
# Name: Type, Length: 1010, dtype: str

# %%
pokemon.apply(len) # applies the len() function to each value in the Series, returning a new Series with the lengths of each value
# Out:
# Name
# Bulbasaur       13
# Ivysaur          4
# Venusaur         5
# Charmander       4
# Charmeleon       3
#                 ..
# Iron Valiant    15
# Koraidon        16
# Miraidon        16
# Walking Wake    13
# Iron Leaves     14
# Name: Type, Length: 1010, dtype: int64

# %%
def count_of_a(s):
    return s.count("a")

pokemon.apply(count_of_a) # applies the count_of_a() function to each value in the Series, returning a new Series with the count of "a" in each value
# Out:
# Name
# Bulbasaur       1
# Ivysaur         0
# Venusaur        1
# Charmander      0
# Charmeleon      0
#                ..
# Iron Valiant    1
# Koraidon        1
# Miraidon        1
# Walking Wake    2
# Iron Leaves     1
# Name: Type, Length: 1010, dtype: int64

# %%
# The map() method is similar to apply(), but it is used for mapping values in a Series to new values based on a mapping dictionary or a function.

pokemon.map(len) # maps the len() function to each value in the Series, returning a new Series with the lengths of each value
# Out:
# Name
# Bulbasaur       13
# Ivysaur          4
# Venusaur         5
# Charmander       4
# Charmeleon       3
#                 ..
# Iron Valiant    15
# Koraidon        16
# Miraidon        16
# Walking Wake    13
# Iron Leaves     14
# Name: Type, Length: 1010, dtype: int64

# %%
attack_powers = { "Grass": 10, "Fire": 20, "Water": 15, "Bug": 5, "Poison": 8 }
pokemon.map(attack_powers) # maps the attack_powers dictionary to each value in the Series, returning a new Series with the corresponding attack power for each type of Pokemon (NaN for
# Out:
# Name
# Bulbasaur        NaN
# Ivysaur         20.0
# Venusaur        15.0
# Charmander      20.0
# Charmeleon       5.0
#                 ...
# Iron Valiant     NaN
# Koraidon         NaN
# Miraidon         NaN
# Walking Wake     NaN
# Iron Leaves      NaN
# Name: Type, Length: 1010, dtype: float64

# %%
attack_powers = pd.Series({ "Grass": 10, "Fire": 20, "Water": 15, "Bug": 5, "Poison": 8 })
pokemon.map(attack_powers) # maps the attack_powers Series to each value in the Series, returning a new Series with the corresponding attack power for each type of Pokemon (NaN for values not found in the attack_powers Series)
# Out:
# Name
# Bulbasaur        NaN
# Ivysaur         20.0
# Venusaur        15.0
# Charmander      20.0
# Charmeleon       5.0
#                 ...
# Iron Valiant     NaN
# Koraidon         NaN
# Miraidon         NaN
# Walking Wake     NaN
# Iron Leaves      NaN
# Name: Type, Length: 1010, dtype: float64

# %%
s = pd.Series([4,8,6,5,3,7])
7 in s.values != 10 in s.values # checks if the value 7 is in the Series and if the value 10 is in the Series, returning True if both conditions are met and False otherwise
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 2
#       1 s = pd.Series([4,8,6,5,3,7])
# ----> 2 7 in s.values != 10 in s.values # checks if the value 7 is in the Series and if the value 10 is in the Series, returning True if both conditions are met and False otherwise
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
s = pd.Series([4,8,6,5,3,7])
s.mean()
